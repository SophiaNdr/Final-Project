# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('13026206-a816-4e28-b1f9-41c964a83c05_Data.csv')

# %%
df
# Out:
#                                          Series Name     Series Code  \
# 0             CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# 1             CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# 2             CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# 3             CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# 4             CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# 5                                  GDP (current US$)  NY.GDP.MKTP.CD
# 6                                  GDP (current US$)  NY.GDP.MKTP.CD
# 7                                  GDP (current US$)  NY.GDP.MKTP.CD
# 8                                  GDP (current US$)  NY.GDP.MKTP.CD
# 9                                  GDP (current US$)  NY.GDP.MKTP.CD
# 10           Life expectancy at birth, total (years)  SP.DYN.LE00.IN
# 11           Life expectancy at birth, total (years)  SP.DYN.LE00.IN
# 12           Life expectancy at birth, total (years)  SP.DYN.LE00.IN
# ...

# %%
f=df.T

# %%
f
# Out:
#                                                    0   \
# Series Name    CO2 emissions (metric tons per capita)
# Series Code                            EN.ATM.CO2E.PC
# Country Name                           United Kingdom
# Country Code                                      GBR
# 2011 [YR2011]                        7.02542460093701
# 2012 [YR2012]                        7.33247132682362
# 2013 [YR2013]                        7.06490255865771
# 2014 [YR2014]                        6.42159819144514
# 2015 [YR2015]                        6.14854495774701
# 2016 [YR2016]                        5.77474166798541
# 2017 [YR2017]                        5.54626594443601
# 2018 [YR2018]                        5.39870813789348
# 2019 [YR2019]                                      ..
# 2020 [YR2020]                                      ..
#
#                                                    1   \
# Series Name    CO2 emissions (metric tons per capita)
# ...

# %%
f=f.rename(columns=f.iloc[0])
f
# Out:
#                CO2 emissions (metric tons per capita)  \
# Series Name    CO2 emissions (metric tons per capita)
# Series Code                            EN.ATM.CO2E.PC
# Country Name                           United Kingdom
# Country Code                                      GBR
# 2011 [YR2011]                        7.02542460093701
# 2012 [YR2012]                        7.33247132682362
# 2013 [YR2013]                        7.06490255865771
# 2014 [YR2014]                        6.42159819144514
# 2015 [YR2015]                        6.14854495774701
# 2016 [YR2016]                        5.77474166798541
# 2017 [YR2017]                        5.54626594443601
# 2018 [YR2018]                        5.39870813789348
# 2019 [YR2019]                                      ..
# 2020 [YR2020]                                      ..
#
#                CO2 emissions (metric tons per capita)  \
# Series Name    CO2 emissions (metric tons per capita)
# ...

# %%
f.to_csv('file.csv')
