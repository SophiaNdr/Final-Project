# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('631c5b93-2d7c-439a-9f0b-98c1165ca10b_Data.csv')

# %%
df
# Out:
#                                            Series Name  \
# 0    Adequacy of unemployment benefits and ALMP (% ...
# 1    Adequacy of unemployment benefits and ALMP (% ...
# 2    Adequacy of unemployment benefits and ALMP (% ...
# 3    Adequacy of unemployment benefits and ALMP (% ...
# 4    Adequacy of unemployment benefits and ALMP (% ...
# ..                                                 ...
# 215                                                NaN
# 216                                                NaN
# 217                                                NaN
# 218   Data from database: World Development Indicators
# 219                           Last Updated: 07/30/2021
#
#                   Series Code    Country Name Country Code 2016 [YR2016]  \
# 0    per_lm_alllm.adq_pop_tot  United Kingdom          GBR            ..
# 1    per_lm_alllm.adq_pop_tot          France          FRA            ..
# 2    per_lm_alllm.adq_pop_tot   United States          USA            ..
# ...
